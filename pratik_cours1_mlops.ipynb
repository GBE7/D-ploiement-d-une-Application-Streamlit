# %% [markdown]
# ## Installation de streamlit dans l'environnement virtuel

# %%
# %pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Initialisation à la visualisation des données

# %%
# %pip install pandas matplotlib seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os

data = {
    "age":[25, 30, 35, 40, 45],
    "salaire": [50000 , 60000, 70000, 80000, 90000],
    "expérience": [2, 5, 8, 10, 12]
}
df = pd.DataFrame(data)

os.makedirs("MLOPS_DAH", exist_ok=True)
df.to_csv("MLOPS_DAH/app_data.csv", index=False)
